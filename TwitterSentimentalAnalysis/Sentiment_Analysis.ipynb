# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /home/umama/anaconda3/lib/python3.7/site-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/umama/anaconda3/lib/python3.7/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /home/umama/anaconda3/lib/python3.7/site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /home/umama/anaconda3/lib/python3.7/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in /home/umama/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Requirement already satisfied: tweepy in /home/umama/anaconda3/lib/python3.7/site-packages (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/umama/anaconda3/lib/python3.7/site-packages (from tweepy) (1.2.0)
# Requirement already satisfied: six>=1.10.0 in /home/umama/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /home/umama/anaconda3/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/umama/anaconda3/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/umama/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/umama/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/umama/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/umama/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/umama/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2019.3.9)
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 565kB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  I would say this is surveillance not managemen...
# 1  At first she was thought to be a lost child in...
# 2  RT @neo4j: "By enhancing artificial intelligen...
# 3  RT @MakelifeBetterM: Why Artificial Intelligen...
# 4  RT @rossdawson: Conversational AI for the elde...
# 5  #ThankWeek: 60 Speakers Scheduled to Present a...
# 6  RT @grattongirl: Artificial Intelligence expla...
# 7  How #Blockchain Can Transform #ArtificialIntel...
# 8  RT @daily_trust: Data science, artificial inte...
# 9  RT @mbrasneves: Presentation at the #eTwinning...
# 2019-07-02 01:05:54

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/umama/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   I would say this is surveillance not managemen...
# 1   At first she was thought to be a lost child in...
# 2   RT @neo4j: "By enhancing artificial intelligen...
# 3   RT @MakelifeBetterM: Why Artificial Intelligen...
# 4   RT @rossdawson: Conversational AI for the elde...
# 5   #ThankWeek: 60 Speakers Scheduled to Present a...
# 6   RT @grattongirl: Artificial Intelligence expla...
# 7   How #Blockchain Can Transform #ArtificialIntel...
# 8   RT @daily_trust: Data science, artificial inte...
# 9   RT @mbrasneves: Presentation at the #eTwinning...
# 10  Join us for our next innovative @PSU_cepe even...
# 11  #CyberDigest | Artificial Intelligence: comput...
# 12  A more effective seasonal flu vaccine develope...
# 13  @MizumoriMidori 身内の私学に国費を使ってますから\nバク・クネちゃんと一緒に...
# 14  The Complete Beginners' Guide to Artificial In...
# 15  #visualcontenting #contentmarketing #socialmed...
# 16  Artificial intelligence fights invasive specie...
# 17  What's Driving the Artificial Intelligence in ...
# 18  RT @RichardKe11y: How ethical are your #AI sys...
# 19  Public Concern Around Use Of Artificial Intell...
# 20  #ArtificialTechnology has added a personal tou...
# 21  RT @NzVox: How Artificial Intelligence Helps I...
# 22  RT @JanelleCShane: “Song titles, paint colors,...
# 23  RT @techreview: This is how artificial intelli...
# 24  RT @into_AI: Public Concern Around Use Of Arti...
# 25  RT @techreview: This is how artificial intelli...
# 26  8 Real-Life Applications of Artificial Intelli...
# 27  Artificial Intelligence classifies people’s em...
# 28  Contact centres will start to rely more heavil...
# 29  Public Concern Around Use Of Artificial Intell...
# ..                                                ...
# 67  jason Kenney is totally and completely irrespo...
# 68  RT @IPSdesigners: What’s the Difference Betwee...
# 69  Inconvenience store: Tacoma shop’s facial reco...
# 70  Inconvenience store: Tacoma shop’s facial reco...
# 71  Inconvenience store: Tacoma shop's facial reco...
# 72  UCP not committed to NDP's previously announce...
# 73  RT @SBSNews: An Australian influenza vaccine b...
# 74  Inconvenience store: Tacoma shop’s facial reco...
# 75  An interesting article from @BNDarticles discu...
# 76  RT @techreview: This is how artificial intelli...
# 77  Inconvenience store: Tacoma shop’s facial reco...
# 78  RT @rossdawson: Conversational AI for the elde...
# 79  👁‍🗨 https://t.co/IAfbp7yTJb — Data science, ar...
# 80  RT @maxjcm: Banking Brands Need #AI to Keep Pa...
# 81  RT @maxjcm: How #AI artificial intelligence ca...
# 82  RT @AINewsletter: #bigdata\n---\nArtificial In...
# 83  Perhaps "artificial" is too artificial of a wo...
# 84  RT @MarkStaples_CIO: How AI and Machine Learni...
# 85  Do you trust or fear artificial intelligence? ...
# 86  RT @JanelleCShane: “Song titles, paint colors,...
# 87                            https://t.co/3CEGTKbMSg
# 88  An #AI #toothbrush... because why not? 🦷 https...
# 89  This is how artificial intelligence can help s...
# 90  RT @maxjcm: #Robotic arm packs boxes with #AI ...
# 91  Q: what did the leftist say when Modi appointe...
# 92  China's AI Package for Africa Includes Mass Su...
# 93  RT @welcomedwelling: Artificial Intelligence N...
# 94  AI+ NEWS * How will artificial intelligence ch...
# 95  #TechnologyNews and #business | Inconvenience ...
# 96  Inconvenience store: Tacoma shop's facial reco...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.103, 'neu': 0.759, 'pos': 0.138, 'co...
# 2   {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 3   {'neg': 0.0, 'neu': 0.521, 'pos': 0.479, 'comp...
# 4   {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 5   {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 6   {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8   {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 9   {'neg': 0.114, 'neu': 0.796, 'pos': 0.09, 'com...
# 10  {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'comp...
# 11  {'neg': 0.133, 'neu': 0.564, 'pos': 0.303, 'co...
# 12  {'neg': 0.123, 'neu': 0.731, 'pos': 0.146, 'co...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 15  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 16  {'neg': 0.25, 'neu': 0.463, 'pos': 0.287, 'com...
# 17  {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'comp...
# 18  {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...
# 19  {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'comp...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'comp...
# 22  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 23  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 24  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 25  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 26  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 27  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 28  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'comp...
# 29  {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'comp...
# ..                                                ...
# 67  {'neg': 0.151, 'neu': 0.61, 'pos': 0.239, 'com...
# 68  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 69  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...
# 70  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...
# 71  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...
# 72  {'neg': 0.122, 'neu': 0.671, 'pos': 0.208, 'co...
# 73  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 74  {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'comp...
# 75  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'comp...
# 76  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 77  {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'comp...
# 78  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 79  {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'comp...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'comp...
# 82  {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'comp...
# 83  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 84  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...
# 85  {'neg': 0.193, 'neu': 0.422, 'pos': 0.386, 'co...
# 86  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 87  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'comp...
# 93  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 94  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 95  {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'comp...
# 96  {'neg': 0.371, 'neu': 0.629, 'pos': 0.0, 'comp...
#
# [97 rows x 2 columns]

# %%
#
